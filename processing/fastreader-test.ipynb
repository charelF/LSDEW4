# %%
from fastreader import fastreader

# inputfilepath = "../exploration/sample.txt"
inputfilepath = "../data/pageviews-20210101-automated"
outputfilepath = "../data/temp/out.parquet"

fastreader(inputfilepath, outputfilepath)
# Out:
# begin processing on file: ../data/pageviews-20210101-automated
# lines read: 1M
# lines read: 2M
# lines read: 3M
# lines read: 4M
# lines read: 5M
# lines read: 6M
# lines read: 7M
# lines read: 8M
# lines read: 9M
# convert list to dataframe
# write parquet to file: ../data/temp/out.parquet (may take some time due to partitioning)

# %%
print("input")
# !ls -l "../data/pageviews-20210101-automated"
print("output")
# !ls -lR "../data/temp/out.parquet"
# Out:
# input
# -rw-r--r--@ 1 charelfelten  staff  499808255 Oct  2 18:03 ../data/pageviews-20210101-automated
# output
# total 0
# drwxr-xr-x  3 charelfelten  staff  96 Oct  6 19:34 year=2021
#
# ../data/temp/out.parquet/year=2021:
# total 0
# drwxr-xr-x  3 charelfelten  staff  96 Oct  6 19:34 month=01
#
# ../data/temp/out.parquet/year=2021/month=01:
# total 0
# drwxr-xr-x  5 charelfelten  staff  160 Oct  6 19:52 day=01
#
# ../data/temp/out.parquet/year=2021/month=01/day=01:
# total 787936
# -rw-r--r--  1 charelfelten  staff  195645769 Oct  6 19:36 74244e3ce6804b4cb8dc2e155e8c8405.parquet
# -rw-r--r--  1 charelfelten  staff  195645769 Oct  6 19:52 b7f329f5add246ddac777584221584ab.parquet
# -rw-r--r--  1 charelfelten  staff      21776 Oct  6 19:34 c0dba7f552a343d391e505fcc607b062.parquet

# %%
import pandas as pd
pd.read_parquet(outputfilepath)
# Out:
#                 domain                  title    id access_type total hour  \
# 0         aa.wikibooks              Main_Page    -1     desktop     8    5
# 1         aa.wikibooks           Special:Book    -1     desktop     1    5
# 2         aa.wikibooks   Special:CiteThisPage    -1     desktop     1    5
# 3         aa.wikibooks  Special:DownloadAsPdf    -1     desktop     1    5
# 4         aa.wikibooks   Special:SpecialPages    -1     desktop     1    5
# ...                ...                    ...   ...         ...   ...  ...
# 12851071  af.wikipedia               820_v.C.  4914     desktop     1   18
# 12851072  af.wikipedia                    821  2947     desktop     1   11
# 12851073  af.wikipedia               834_v.C.  4914     desktop     1   13
# 12851074  af.wikipedia                    843  2969     desktop     2   14
# 12851075  af.wikipedia                    843  2969     desktop     2   22
#
#          count traffic_type  year month day
# ...
